# %%
import numpy as np
import pandas as pd

# %%
refmat = np.load('clu_0_2_dpi_dblt_filtd_jaspar2022_chromvar.npy')

# %%
refmat
# Out:
# array([[-0.35492716, -0.96050948,  1.2131949 , ..., -1.42436782,
#         -0.01206464, -1.68174825],
#        [ 0.48761344, -0.68703988,  0.05190809, ...,  0.21139343,
#         -1.60951722, -0.90134261],
#        [-1.2864553 ,  0.0095194 , -0.74561664, ..., -0.67540283,
#         -1.71996263, -1.4597088 ],
#        ...,
#        [-0.01862098,  0.36506953,  0.439903  , ...,  1.21251997,
#         -0.26650615,  1.45738246],
#        [-0.55100596,  0.34132083, -0.56109293, ...,  0.76770086,
#         -1.58289522, -1.44269518],
#        [-0.10949761,  1.34207299,  0.73652772, ..., -0.84630343,
#         -0.26052107, -0.6335778 ]])

# %%
tfs = pd.read_csv('clu_0_2_dpi_dblt_filtd_jaspar2022_motifnames.csv', index_col = 0)

# %%
tfs
# Out:
#                     V1
# MA0004.1          Arnt
# MA0006.1     Ahr::Arnt
# MA0019.1  Ddit3::Cebpa
# MA0029.1         Mecom
# MA0030.1         FOXF2
# ...                ...
# MA1630.2        ZNF281
# MA1633.2         BACH1
# MA1647.2         Prdm4
# MA0597.2         THAP1
# MA1540.2         NR5A1
#
# [841 rows x 1 columns]

# %%
meta = pd.read_csv('clu_0_2_dpi_dblt_filtd_meta_rezonationed_redone2.csv', index_col = 0)

# %%
np.where(tfs['V1'] == 'Atoh1')
# Out:
# (array([252, 818]),)

# %%
tfs.rename(columns = {'V1': 'names'}, inplace = True)

# %%
tfs.reset_index(drop = False, inplace = True)

# %%
import seaborn as sns; sns.set_theme(color_codes=True)
import matplotlib.colors as clr
import matplotlib.pyplot as plt

# %%
cluster_tfs = pd.read_csv('clu_0_2_dpi_dblt_filtd_cluster_motifs_main_newcollapse_idents2_rezonationed_mean.csv', index_col= 0)

# %%
cluster_tfs
# Out:
#                          motif  observed  background  percent.observed  \
# Enterocytes.MA0599.1  MA0599.1       485       10313         64.494681
# Enterocytes.MA0039.4  MA0039.4       477       10257         63.430851
# Enterocytes.MA0493.2  MA0493.2       453        9256         60.239362
# Enterocytes.MA1961.1  MA1961.1       410        7838         54.521277
# Enterocytes.MA1511.2  MA1511.2       413        8019         54.920213
# ...                        ...       ...         ...               ...
# Immune.MA1144.1       MA1144.1       180        4374          5.678233
# Immune.MA0655.1       MA0655.1       132        3241          4.164038
# Immune.MA1138.1       MA1138.1       169        4182          5.331230
# Immune.MA0491.2       MA0491.2       159        3971          5.015773
# Immune.MA0490.2       MA0490.2       154        3958          4.858044
#
#                       percent.background  fold.enrichment         pvalue  \
# Enterocytes.MA0599.1             25.7825         2.501491  3.043334e-112
# Enterocytes.MA0039.4             25.6425         2.473661  2.273270e-107
# Enterocytes.MA0493.2             23.1400         2.603257  3.113485e-107
# Enterocytes.MA1961.1             19.5950         2.782408  3.541599e-102
# Enterocytes.MA1511.2             20.0475         2.739504  6.001176e-101
# ...                                  ...              ...            ...
# Immune.MA1144.1                  10.9350         0.519271   1.000000e+00
# Immune.MA0655.1                   8.1025         0.513920   1.000000e+00
# Immune.MA1138.1                  10.4550         0.509922   1.000000e+00
# Immune.MA0491.2                   9.9275         0.505240   1.000000e+00
# Immune.MA0490.2                   9.8950         0.490959   1.000000e+00
#
#                        motif.name       p.adjust      cluster
# Enterocytes.MA0599.1         KLF5  2.559444e-109  Enterocytes
# Enterocytes.MA0039.4         KLF4  8.728135e-105  Enterocytes
# Enterocytes.MA0493.2         KLF1  8.728135e-105  Enterocytes
# Enterocytes.MA1961.1        PATZ1  7.446211e-100  Enterocytes
# Enterocytes.MA1511.2        KLF10   1.009398e-98  Enterocytes
# ...                           ...            ...          ...
# Immune.MA1144.1       FOSL2::JUND   1.000000e+00       Immune
# Immune.MA0655.1              JDP2   1.000000e+00       Immune
# Immune.MA1138.1       FOSL2::JUNB   1.000000e+00       Immune
# Immune.MA0491.2              JUND   1.000000e+00       Immune
# Immune.MA0490.2              JUNB   1.000000e+00       Immune
#
# [7569 rows x 10 columns]

# %%
cluster_tfs.cluster.unique()
# Out:
# array(['Enterocytes', 'RevSC1-W13', 'Crypt Cells', 'Paneth Cells',
#        'Tuft Cells', 'Enteroendocrine Cells', 'Goblet Cells',
#        'Fibroblasts', 'Immune'], dtype=object)

# %%
cluster_tfs.loc[cluster_tfs['cluster'] == 'RevSC1-W13',][1:25]
# Out:
#                         motif  observed  background  percent.observed  \
# RevSC1-W13.MA1128.1  MA1128.1      1199        6098         45.903522
# RevSC1-W13.MA0476.1  MA0476.1      1204        6174         46.094946
# RevSC1-W13.MA0489.2  MA0489.2      1252        6502         47.932619
# RevSC1-W13.MA1928.1  MA1928.1      1257        6607         48.124043
# RevSC1-W13.MA1634.1  MA1634.1      1255        6731         48.047473
# RevSC1-W13.MA1988.1  MA1988.1      1334        7164         51.071975
# RevSC1-W13.MA0462.2  MA0462.2      1258        6763         48.162328
# RevSC1-W13.MA0835.2  MA0835.2      1251        6763         47.894334
# RevSC1-W13.MA0477.2  MA0477.2      1180        6056         45.176110
# RevSC1-W13.MA0478.1  MA0478.1      1167        5954         44.678407
# RevSC1-W13.MA1130.1  MA1130.1      1144        5785         43.797856
# RevSC1-W13.MA1137.1  MA1137.1      1125        5735         43.070444
# RevSC1-W13.MA1144.1  MA1144.1      1091        5460         41.768760
# RevSC1-W13.MA1135.1  MA1135.1      1072        5322         41.041348
# RevSC1-W13.MA0099.3  MA0099.3      1091        5539         41.768760
# RevSC1-W13.MA1134.1  MA1134.1      1054        5208         40.352221
# RevSC1-W13.MA1142.1  MA1142.1      1099        5676         42.075038
# RevSC1-W13.MA1138.1  MA1138.1      1065        5368         40.773354
# RevSC1-W13.MA0491.2  MA0491.2      1007        5186         38.552833
# RevSC1-W13.MA0490.2  MA0490.2      1012        5375         38.744257
# RevSC1-W13.MA1633.2  MA1633.2       999        5276         38.246554
# RevSC1-W13.MA0655.1  MA0655.1       855        4381         32.733538
# RevSC1-W13.MA1132.1  MA1132.1       815        4375         31.202144
# RevSC1-W13.MA0841.1  MA0841.1       765        3948         29.287902
#
#                      percent.background  fold.enrichment         pvalue  \
# RevSC1-W13.MA1128.1             15.2450         3.011054   0.000000e+00
# RevSC1-W13.MA0476.1             15.4350         2.986391   0.000000e+00
# RevSC1-W13.MA0489.2             16.2550         2.948792   0.000000e+00
# RevSC1-W13.MA1928.1             16.5175         2.913519   0.000000e+00
# RevSC1-W13.MA1634.1             16.8275         2.855295   0.000000e+00
# RevSC1-W13.MA1988.1             17.9100         2.851590   0.000000e+00
# RevSC1-W13.MA0462.2             16.9075         2.848578   0.000000e+00
# RevSC1-W13.MA0835.2             16.9075         2.832727  2.411040e-320
# RevSC1-W13.MA0477.2             15.1400         2.983891  6.506845e-320
# RevSC1-W13.MA0478.1             14.8850         3.001573  5.254191e-318
# RevSC1-W13.MA1130.1             14.4625         3.028374  7.216373e-314
# RevSC1-W13.MA1137.1             14.3375         3.004041  1.071637e-303
# RevSC1-W13.MA1144.1             13.6500         3.059982  8.381810e-300
# RevSC1-W13.MA1135.1             13.3050         3.084656  1.472401e-296
# RevSC1-W13.MA0099.3             13.8475         3.016339  9.212993e-294
# RevSC1-W13.MA1134.1             13.0200         3.099249  2.982916e-292
# RevSC1-W13.MA1142.1             14.1900         2.965119  2.758372e-289
# RevSC1-W13.MA1138.1             13.4200         3.038253  6.602422e-288
# RevSC1-W13.MA0491.2             12.9650         2.973608  2.823974e-260
# RevSC1-W13.MA0490.2             13.4375         2.883294  3.530417e-250
# RevSC1-W13.MA1633.2             13.1900         2.899663  2.737725e-248
# RevSC1-W13.MA0655.1             10.9525         2.988682  5.739371e-215
# RevSC1-W13.MA1132.1             10.9375         2.852767  2.740819e-189
# RevSC1-W13.MA0841.1              9.8700         2.967366  1.319731e-186
#
#                       motif.name       p.adjust     cluster
# RevSC1-W13.MA1128.1   FOSL1::JUN   0.000000e+00  RevSC1-W13
# RevSC1-W13.MA0476.1          FOS   0.000000e+00  RevSC1-W13
# RevSC1-W13.MA0489.2          Jun   0.000000e+00  RevSC1-W13
# RevSC1-W13.MA1928.1         BNC2   0.000000e+00  RevSC1-W13
# RevSC1-W13.MA1634.1         BATF   0.000000e+00  RevSC1-W13
# RevSC1-W13.MA1988.1         Atf3   0.000000e+00  RevSC1-W13
# RevSC1-W13.MA0462.2    BATF::JUN   0.000000e+00  RevSC1-W13
# RevSC1-W13.MA0835.2        BATF3  2.252984e-318  RevSC1-W13
# RevSC1-W13.MA0477.2        FOSL1  5.472256e-318  RevSC1-W13
# RevSC1-W13.MA0478.1        FOSL2  4.017067e-316  RevSC1-W13
# RevSC1-W13.MA1130.1   FOSL2::JUN  5.057475e-312  RevSC1-W13
# RevSC1-W13.MA1137.1  FOSL1::JUNB  6.932665e-302  RevSC1-W13
# RevSC1-W13.MA1144.1  FOSL2::JUND  5.035073e-298  RevSC1-W13
# RevSC1-W13.MA1135.1   FOSB::JUNB  8.255263e-295  RevSC1-W13
# RevSC1-W13.MA0099.3     FOS::JUN  4.842580e-292  RevSC1-W13
# RevSC1-W13.MA1134.1    FOS::JUNB  1.475666e-290  RevSC1-W13
# RevSC1-W13.MA1142.1  FOSL1::JUND  1.288773e-287  RevSC1-W13
# RevSC1-W13.MA1138.1  FOSL2::JUNB  2.922441e-286  RevSC1-W13
# RevSC1-W13.MA0491.2         JUND  1.187481e-258  RevSC1-W13
# RevSC1-W13.MA0490.2         JUNB  1.413848e-248  RevSC1-W13
# RevSC1-W13.MA1633.2        BACH1  1.046558e-246  RevSC1-W13
# RevSC1-W13.MA0655.1         JDP2  2.098614e-213  RevSC1-W13
# RevSC1-W13.MA1132.1    JUN::JUNB  9.604287e-188  RevSC1-W13
# RevSC1-W13.MA0841.1         NFE2  4.439574e-185  RevSC1-W13

# %%
cluster_tfs = cluster_tfs.groupby('cluster').head(150)

# %%
cluster_tfs = cluster_tfs['motif.name'].unique()

# %%
smads_toadd = [x for x in ['SMAD2', 'SMAD3', 'Smad4'] if x not in cluster_tfs]

# %%
cluster_tfs = np.append(cluster_tfs, smads_toadd)

# %%
tfsoi = np.hstack([np.where(tfs['names'] == x)[0] for x in cluster_tfs])

# %%
refmat[tfsoi,:]
# Out:
# array([[-0.27210223, -0.345081  , -0.8173614 , ..., -0.20358885,
#         -0.43487283, -0.29845688],
#        [-0.57375714, -0.58398724, -0.24621173, ...,  0.13113719,
#         -0.24544889,  0.13123471],
#        [ 0.06327058, -0.82602008, -1.10981036, ...,  0.08304198,
#         -0.3987359 , -0.36959605],
#        ...,
#        [-0.86392797, -0.92063618, -0.39028135, ..., -0.0689505 ,
#          0.46026317, -0.07248573],
#        [ 0.63764755,  0.03190413, -3.11684691, ..., -0.00592863,
#          1.06893354, -0.92592655],
#        [ 0.34172999, -1.06079108, -2.6746899 , ...,  0.25321238,
#         -0.59140361, -0.54816232]])

# %%
meta.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'scrub', 'gex_barcode',
#        'atac_barcode', 'is_cell', 'excluded_reason', 'gex_raw_reads',
#        'gex_mapped_reads',
#        ...
#        'villus_bottom', 'villus_mid', 'villus_top', 'zonation2',
#        'collapse_idents', 'new_rna_clusters', 'smads', 'teads',
#        'new_collapse_idents', 'new_collapse_idents2'],
#       dtype='object', length=132)

# %%
cluster_tfscore = pd.DataFrame(index = meta['new_collapse_idents2'].unique(), columns = cluster_tfs)
cluster_tfscoresizes = pd.DataFrame(index = meta['new_collapse_idents2'].unique(), columns = cluster_tfs)

# %%
cluster_tfscore
# Out:
#                       KLF5 KLF4 KLF1 PATZ1 KLF10 KLF2 KLF14  SP4 ZNF148 KLF15  \
# Immune                 NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Enterocytes            NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# RevSC1-W13             NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Paneth Cells           NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Goblet Cells           NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Enteroendocrine Cells  NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Fibroblasts            NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Crypt Cells            NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Tuft Cells             NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
#
#                        ... ELK1::HOXB13 CREB3 Ikzf3 TFEC Atf1 CREM ELF1 Creb5  \
# Immune                 ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Enterocytes            ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# RevSC1-W13             ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Paneth Cells           ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Goblet Cells           ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Enteroendocrine Cells  ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Fibroblasts            ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Crypt Cells            ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Tuft Cells             ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
#
#                       SMAD3 Smad4
# Immune                  NaN   NaN
# Enterocytes             NaN   NaN
# RevSC1-W13              NaN   NaN
# Paneth Cells            NaN   NaN
# Goblet Cells            NaN   NaN
# Enteroendocrine Cells   NaN   NaN
# Fibroblasts             NaN   NaN
# Crypt Cells             NaN   NaN
# Tuft Cells              NaN   NaN
#
# [9 rows x 363 columns]

# %%
np.mean(refmat[np.where(tfs['names'] == 'Atoh1')[0],:][:,np.where(meta['new_collapse_idents2'] == 'RevSC1')[0]])
# Out:
# /home/shyam/anaconda3/envs/makr/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/shyam/anaconda3/envs/makr/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
np.mean(refmat[np.where(tfs['names'] == 'Atoh1')[0],:][:,np.where(meta['new_collapse_idents2'] == 'RevSC1')[0]][0])
# Out:
# nan

# %%
cluster_tfscore
# Out:
#                       KLF5 KLF4 KLF1 PATZ1 KLF10 KLF2 KLF14  SP4 ZNF148 KLF15  \
# Immune                 NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Enterocytes            NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# RevSC1-W13             NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Paneth Cells           NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Goblet Cells           NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Enteroendocrine Cells  NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Fibroblasts            NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Crypt Cells            NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
# Tuft Cells             NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN    NaN   NaN
#
#                        ... ELK1::HOXB13 CREB3 Ikzf3 TFEC Atf1 CREM ELF1 Creb5  \
# Immune                 ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Enterocytes            ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# RevSC1-W13             ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Paneth Cells           ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Goblet Cells           ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Enteroendocrine Cells  ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Fibroblasts            ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Crypt Cells            ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# Tuft Cells             ...          NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
#
#                       SMAD3 Smad4
# Immune                  NaN   NaN
# Enterocytes             NaN   NaN
# RevSC1-W13              NaN   NaN
# Paneth Cells            NaN   NaN
# Goblet Cells            NaN   NaN
# Enteroendocrine Cells   NaN   NaN
# Fibroblasts             NaN   NaN
# Crypt Cells             NaN   NaN
# Tuft Cells              NaN   NaN
#
# [9 rows x 363 columns]

# %%
tfs
# Out:
#         index         names
# 0    MA0004.1          Arnt
# 1    MA0006.1     Ahr::Arnt
# 2    MA0019.1  Ddit3::Cebpa
# 3    MA0029.1         Mecom
# 4    MA0030.1         FOXF2
# ..        ...           ...
# 836  MA1630.2        ZNF281
# 837  MA1633.2         BACH1
# 838  MA1647.2         Prdm4
# 839  MA0597.2         THAP1
# 840  MA1540.2         NR5A1
#
# [841 rows x 2 columns]

# %%
for cluster in cluster_tfscore.index:
    for tf in cluster_tfscore.columns:
        if tf == 'FOS::JUN':
            cluster_tfscore.loc[cluster, tf] = np.mean(refmat[np.where(tfs['index'] == 'MA0099.3')[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])
            if cluster_tfscore.loc[cluster, tf] > 0:
                #cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] > np.mean(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
                cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['index'] == 'MA0099.3')[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] > 0) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
            elif cluster_tfscore.loc[cluster, tf] < 0:
                #cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] < np.mean(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
                cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['index'] == 'MA0099.3')[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] < 0) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
            else: 
                cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['index'] == 'MA0099.3')[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] == np.mean(refmat[np.where(tfs['index'] == 'MA0099.3')[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
        else:
            
            cluster_tfscore.loc[cluster, tf] = np.mean(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])
            if cluster_tfscore.loc[cluster, tf] > 0:
                #cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] > np.mean(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
                cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] > 0) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
            elif cluster_tfscore.loc[cluster, tf] < 0:
                #cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] < np.mean(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
                cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] < 0) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
            else: 
                cluster_tfscoresizes.loc[cluster, tf] = np.count_nonzero(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]] == np.mean(refmat[np.where(tfs['names'] == tf)[0],:][:,np.where(meta['new_collapse_idents2'] == cluster)[0]])) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])

# %%
tf_names = ['TEAD', 'HNF1']

# %%
for tf_name in tf_names:
    cluster_tfscoresizes[tf_name] = 0
    cluster_tfscore[tf_name] = 0

# %%
refmat[np.hstack([np.where(tfs['names'] == x)[0] for x in ['TEAD1', 'TEAD2', 'TEAD3', 'TEAD4']]),: ][:,np.where(meta['new_collapse_idents2'] == 'RevSC1')[0]].max(axis = 0).mean()
# Out:
# /tmp/ipykernel_9923/1889970753.py:1: RuntimeWarning: Mean of empty slice.
#   refmat[np.hstack([np.where(tfs['names'] == x)[0] for x in ['TEAD1', 'TEAD2', 'TEAD3', 'TEAD4']]),: ][:,np.where(meta['new_collapse_idents2'] == 'RevSC1')[0]].max(axis = 0).mean()
# /home/shyam/anaconda3/envs/makr/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
for cluster in cluster_tfscore.index:
    
    tf_list = [['TEAD1', 'TEAD2', 'TEAD3', 'TEAD4'], ['HNF1A', 'HNF1B']]
    for tf_i in tf_list:
        cluster_tfscore.loc[cluster, tf_names[tf_list.index(tf_i)]] = refmat[np.hstack([np.where(tfs['names'] == x)[0] for x in tf_i]),: ][:,np.where(meta['new_collapse_idents2'] == cluster)[0]].max(axis = 0).mean()
        if cluster_tfscore.loc[cluster, tf_names[tf_list.index(tf_i)]] > 0:
            cluster_tfscoresizes.loc[cluster, tf_names[tf_list.index(tf_i)]] = np.count_nonzero(refmat[np.hstack([np.where(tfs['names'] == x)[0] for x in tf_i]),: ][:,np.where(meta['new_collapse_idents2'] == cluster)[0]].max(axis = 0) > 0) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
        if cluster_tfscore.loc[cluster, tf_names[tf_list.index(tf_i)]] < 0:
            cluster_tfscoresizes.loc[cluster, tf_names[tf_list.index(tf_i)]] = np.count_nonzero(refmat[np.hstack([np.where(tfs['names'] == x)[0] for x in tf_i]),: ][:,np.where(meta['new_collapse_idents2'] == cluster)[0]].max(axis = 0) < 0) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])
        if cluster_tfscore.loc[cluster, tf_names[tf_list.index(tf_i)]] == 0:
            cluster_tfscoresizes.loc[cluster, tf_names[tf_list.index(tf_i)]] = np.count_nonzero(refmat[np.hstack([np.where(tfs['names'] == x)[0] for x in tf_i]),: ][:,np.where(meta['new_collapse_idents2'] == cluster)[0]].max(axis = 0) == 0) / len(np.where(meta['new_collapse_idents2'] == cluster)[0])

# %%
cluster_tfscore.loc[:,['SMAD2', 'SMAD3', 'Smad4']]
# Out:
#                           SMAD2     SMAD3     Smad4
# Immune                -0.158792  0.164281   -0.0653
# Enterocytes           -0.014654 -0.035479  0.018892
# RevSC1-W13             0.475781 -0.056535  0.133977
# Paneth Cells           0.165237 -0.071318 -0.069405
# Goblet Cells          -0.086081  0.011608 -0.024795
# Enteroendocrine Cells   0.07015  0.027863 -0.127556
# Fibroblasts            0.038692 -0.131157 -0.167863
# Crypt Cells            0.266507  -0.04659  0.073713
# Tuft Cells            -0.716412  0.057595 -0.354833

# %%
cluster_tfscore = cluster_tfscore[cluster_tfscore.columns].astype(float)

# %%
cmap = sns.diverging_palette(210, 353, sep=1, n=256, as_cmap = True)
cmap = sns.blend_palette(['#2166AC','#ffffff' ,'#B2182B'], n_colors=256, as_cmap = True)

# %%
g1 = sns.heatmap(cluster_tfscore, cmap = cmap, center = 0, vmin = -2.5, vmax = 2.5,xticklabels = True, yticklabels = True)

# %%
g1 = sns.clustermap(cluster_tfscore, cmap = cmap, center = 0, vmax = 3.0, xticklabels = True, yticklabels = True)

# %%
g1.figure.set_size_inches(40, 10)

# %%
g1.tick_params(axis='x', which='major', labelsize=5)
g1.tick_params(axis='y', which='major', labelsize=12)

# %%
g1.figure

# %%
#g1.figure.savefig('clu_0_2_dpi_dblt_filtd_chromvar_cluster_wnn_collapse2_test.pdf')

# %%
cc = cluster_tfscore.loc[:,['TEAD','SMAD2','FOS::JUN']]
cc2 = cluster_tfscoresizes.loc[:,['TEAD','SMAD2','FOS::JUN']]

# %%
cc2 = cc2.loc[[ 'RevSC1-W13', 'Crypt Cells', 'Paneth Cells','Enterocytes' , 'Goblet Cells', 'Enteroendocrine Cells', 'Immune'],]
cc = cc.loc[[  'RevSC1-W13', 'Crypt Cells', 'Paneth Cells','Enterocytes' , 'Goblet Cells', 'Enteroendocrine Cells', 'Immune'],]

# %%
#cluster_tfscore['SMAD'] = cluster_tfscore.loc[:,['SMAD2', 'SMAD3', 'Smad4']].mean()
#cluster_tfscore['SMAD'] =  cluster_tfscore.loc[:,['SMAD2', 'SMAD3', 'Smad4']].mean()

# %%
c = np.array(cc)
c2 = np.array(cc2)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection

# %%
cluster_tfscoresizes.loc[:,['TEAD1', 'TEAD2', 'TEAD3', 'TEAD4','FOS::JUN', 'TCF3', 'SNAI1', 'HNF1A', 'HNF1B', 'FOXC1', 'FOXB1', 'FOXD2', 'RFX4', 'Rfx6', 'FOXP1', 'Atoh1']]
# Out:
#                           TEAD1     TEAD2     TEAD3     TEAD4  FOS::JUN  \
# Immune                 0.935558  0.931923  0.940846  0.946134  0.921018
# Enterocytes            0.651836  0.644831  0.645609  0.666234  0.475029
# RevSC1-W13              0.82243  0.813084   0.82866  0.809969  0.984424
# Paneth Cells           0.636066  0.668852  0.655738  0.685246  0.829508
# Goblet Cells           0.656428  0.648464  0.640501  0.663254   0.82025
# Enteroendocrine Cells  0.851406  0.859438  0.899598  0.895582  0.550201
# Fibroblasts                0.64      0.64       0.6      0.72      0.72
# Crypt Cells            0.722222  0.716524  0.702279  0.726496  0.951567
# Tuft Cells               0.6875    0.5625     0.625    0.8125    0.9375
#
#                            TCF3     SNAI1     HNF1A     HNF1B     FOXC1  \
# Immune                 0.852941  0.865829  0.965962  0.973232  0.628553
# Enterocytes            0.503697  0.510053  0.611363   0.60851  0.784019
# RevSC1-W13             0.781931  0.785047  0.753894  0.772586  0.753894
# Paneth Cells           0.911475  0.885246  0.718033  0.708197  0.977049
# Goblet Cells           0.704209  0.758817  0.540387  0.571104  0.963595
# Enteroendocrine Cells  0.638554  0.590361   0.84739  0.855422  0.927711
# Fibroblasts                0.88      0.92      0.84      0.84      0.64
# Crypt Cells             0.77208   0.80057  0.874644   0.88604  0.635328
# Tuft Cells               0.6875     0.625    0.6875       0.5    0.5625
#
#                           FOXB1     FOXD2      RFX4      Rfx6     FOXP1  \
# Immune                 0.636484  0.607733  0.505288  0.598149  0.525777
# Enterocytes            0.785835  0.790634  0.563497  0.592035  0.757556
# RevSC1-W13             0.722741  0.760125  0.576324   0.58567  0.626168
# Paneth Cells           0.980328  0.977049  0.698361  0.718033  0.983607
# Goblet Cells           0.962457  0.967008  0.591581  0.587031  0.954494
# Enteroendocrine Cells  0.955823  0.959839  0.935743  0.935743  0.931727
# Fibroblasts                 0.6       0.6      0.56      0.68      0.44
# Crypt Cells            0.599715   0.68661  0.562678  0.541311  0.566952
# Tuft Cells                0.625      0.75     0.625    0.6875       0.5
#
#                           Atoh1
# Immune                 1.034038
# Enterocytes            1.270723
# RevSC1-W13              1.28972
# Paneth Cells           1.904918
# Goblet Cells           1.767918
# Enteroendocrine Cells  1.710843
# Fibroblasts                1.16
# Crypt Cells            1.162393
# Tuft Cells                 1.25

# %%
from matplotlib.legend_handler import HandlerPatch
import matplotlib.patches as mpatches

# %%
class HandlerEllipse(HandlerPatch):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize, trans):
        center = 0.5 * width - 0.5 * xdescent, 0.5 * height - 0.5 * ydescent
        p = mpatches.Ellipse(xy=center, width=orig_handle.width,
                                        height=orig_handle.height)
        self.update_prop(p, orig_handle, legend)
        p.set_transform(trans)
        return [p]
    #from https://stackoverflow.com/questions/65631607/showing-different-size-circles-in-heatmap-with-legend-using-matplotlib/65654470

# %%
cc2
# Out:
#                            TEAD     SMAD2  FOS::JUN
# RevSC1-W13             0.909657  0.660436  0.984424
# Crypt Cells            0.860399  0.588319  0.951567
# Paneth Cells           0.527869   0.57377  0.829508
# Enterocytes            0.827474  0.512129  0.475029
# Goblet Cells           0.531286  0.527873   0.82025
# Enteroendocrine Cells  0.767068  0.493976  0.550201
# Immune                 0.876735  0.574686  0.921018

# %%
# adapted from https://stackoverflow.com/questions/59381273/heatmap-with-circles-indicating-size-of-population
x, y = np.meshgrid(np.arange(c.shape[1]), np.arange(c.shape[0]))
fig, ax = plt.subplots()
circles = [plt.Circle((j,i), radius=R * 0.25) for R,j, i in zip(c2.flat, x.flat, y.flat)]
col = PatchCollection(circles, array=c.flatten(), cmap=cmap, norm=matplotlib.colors.Normalize(vmin=-1, vmax=1))
#col.set_clim(vmax = 6, vmin = -4)
ax.add_collection(col)


ax.set(xticks=np.arange(c.shape[1]), yticks=np.arange(c.shape[0]),
       xticklabels=cc.columns, yticklabels=cc.index,)
ax.set_xticks(np.arange(c.shape[1]+1)-0.5, minor=True)
ax.set_yticks(np.arange(c.shape[0]+1)-0.5, minor=True)

plt.grid(which='major', color='black')
ax.grid(visible = False)
ax.set_aspect('equal',adjustable="box")
ax.spines['left'].set_color('0.5')
ax.spines['bottom'].set_color('0.5')
ax.set_facecolor((1, 1, 1))
ax.tick_params(bottom=True,
               left=True,color = 'black'
              )
fig.colorbar(col)

plt.ylabel('Identity')
plt.xlabel('Motifs')
plt.xticks(rotation=35, ha='right')
texts = ["10","50","75"]
c = [mpatches.Ellipse((), width=10*0.25, height=10*0.25, color="grey"),
     mpatches.Ellipse((), width=50*0.25, height=50*0.25, color="grey"),
     mpatches.Ellipse((), width=75*0.25, height=75*0.25, color="grey"),
    ]
legend = ax.legend(c,texts, handler_map={mpatches.Ellipse: HandlerEllipse()},title="Percent Expressed",bbox_to_anchor=(3.50, 0.82, 1.0, .102),fontsize="large")
plt.setp(legend.get_title(),fontsize='large')

figg = plt.gca()

# %%
#figg.figure.set_axis_bgcolor("lightslategray")

# %%
figg.collections[0].colorbar.set_label(label = 'Average Z-Score',fontsize = 20)
figg.yaxis.label.set_size(20)
figg.xaxis.label.set_size(20)
figg.tick_params(axis='both', which='major', labelsize=20)
figg.collections[0].colorbar.ax.tick_params(labelsize=20)

# %%
figg.figure.set_size_inches(50, 10)

# %%
figg.figure

# %%
figg.figure.savefig('clu_0_2_dpi_dblt_filtd_dotplot_revsc_motifs_cluster_wise2.pdf')

# %%
cc3 = cluster_tfscore.loc[:,['TCF3', 'SNAI1', 'HNF1','Rxra',
                            'Nr2f6', 'PPARD', 'FOXD2', 'Neurod2', 'Olig2', 'Atoh1', 'ELK4', 'ETV2', 'Spi1']]
cc4 = cluster_tfscoresizes.loc[:,['TCF3', 'SNAI1', 'HNF1','Rxra',
                            'Nr2f6', 'PPARD', 'FOXD2', 'Neurod2', 'Olig2', 'Atoh1', 'ELK4', 'ETV2', 'Spi1']]

# %%
cc4 = cc4.loc[[ 'RevSC1-W13', 'Crypt Cells', 'Paneth Cells','Enterocytes' , 'Goblet Cells', 'Enteroendocrine Cells', 'Immune'],]
cc3 = cc3.loc[[  'RevSC1-W13', 'Crypt Cells', 'Paneth Cells','Enterocytes' , 'Goblet Cells', 'Enteroendocrine Cells', 'Immune'],]

# %%
c3 = np.array(cc3)
c4 = np.array(cc4)

# %%
# adapted from https://stackoverflow.com/questions/59381273/heatmap-with-circles-indicating-size-of-population

x, y = np.meshgrid(np.arange(c3.shape[1]), np.arange(c3.shape[0]))
fig, ax = plt.subplots()
circles = [plt.Circle((j,i), radius=R * 0.25) for R,j, i in zip(c4.flat, x.flat, y.flat)]
col = PatchCollection(circles, array=c3.flatten(), cmap=cmap, norm=matplotlib.colors.Normalize(vmin=-1, vmax=1))
#col.set_clim(vmax = 6, vmin = -4)
ax.add_collection(col)


ax.set(xticks=np.arange(c3.shape[1]), yticks=np.arange(c3.shape[0]),
       xticklabels=cc3.columns, yticklabels=cc3.index,)
ax.set_xticks(np.arange(c3.shape[1]+1)-0.5, minor=True)
ax.set_yticks(np.arange(c3.shape[0]+1)-0.5, minor=True)

plt.grid(which='major', color='black')
ax.grid(visible = False)
ax.set_aspect('equal',adjustable="box")
ax.spines['left'].set_color('0.5')
ax.spines['bottom'].set_color('0.5')
ax.set_facecolor((1, 1, 1))
ax.tick_params(bottom=True,
               left=True,color = 'black'
              )
fig.colorbar(col)

plt.ylabel('Identity')
plt.xlabel('Motifs')
plt.xticks(rotation=35, ha='right')
texts = ["10","50","75"]
c = [mpatches.Ellipse((), width=10*0.25, height=10*0.25, color="grey"),
     mpatches.Ellipse((), width=50*0.25, height=50*0.25, color="grey"),
     mpatches.Ellipse((), width=75*0.25, height=75*0.25, color="grey"),
    ]
legend = ax.legend(c,texts, handler_map={mpatches.Ellipse: HandlerEllipse()},title="Percent Expressed",bbox_to_anchor=(1.0, 0.82, 1.0, .102),fontsize="large")

figg2 = plt.gca()

# %%
figg2.collections[0].colorbar.set_label(label = 'Average Z-Score',fontsize = 20)
figg2.yaxis.label.set_size(20)
figg2.xaxis.label.set_size(20)
figg2.tick_params(axis='both', which='major', labelsize=20)
figg2.collections[0].colorbar.ax.tick_params(labelsize=20)

# %%
figg2.figure.set_size_inches(50, 10)

# %%
figg2.figure

# %%
figg2.figure.savefig('clu_0_2_dpi_dblt_filtd_dotplot_cluster_motifs_cluster_wise2.pdf')
